# %%
import os
import sys
sys.path.insert(0, '/home/nickbarry/Documents/MsC-DS/Data_Science_Research_Project/Coresets/Repositories/HRNet-Semantic-Segmentation-Coreset')
sys.path.insert(0, '/home/nickbarry/Documents/MsC-DS/Data_Science_Research_Project/Coresets/Repositories/HRNet-Semantic-Segmentation-Coreset/lib')
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from .plot_utils import make_line_plot

# %% [markdown]
# #### Global configurations

# %%
sns.set_style("darkgrid")

# %% [markdown]
# # S4.2

# %% [markdown]
# #### Figure 4.2.1

# %%
csv_path = '../plot_csv/section_4/figure_4_2_1.csv'
figure_df = pd.read_csv(csv_path)


# x_column = "step_num"
# y_column = "val"
# hue = (
#         figure_df["coreset_algorithm"].astype(str)
#         + ", "
#         + figure_df["coreset_frac"].astype(str)
#         + ", "
#         + figure_df["sim_metric"].astype(str)
#         + ", "
#         + figure_df["embedding"].astype(str)
#         + ", "
#         + figure_df["embedding"].astype(str)
#         + ", "
#         + figure_df["epsilon"].astype(str)
#     )
# x_label = "Epoch"
# y_label = "placeholder"
# title = "stochastic_sampling_epsilon_experiment"

# %%
make_line_plot(figure_df, x_column, y_column, hue, x_label, y_label, title)
