# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import  pyplot as plt

# %%
d = {'datasets':['cifar10-ResNet18', 'cifar10-ResNet101', 'cifar100-ResNet18', 'cifar100-ResNet101', 'TinyImageNet-ResNet18','TinyImageNet-ResNet101', 'Pascal_CTX (ours)'], 'deltas':[(94.12-94.05)/(100-94.05), (94.24-94.2)/(100-94.2), (74.95-74.82)/(100-74.95), (75.28-73.21)/(100-75.28), (50.56-50.3)/(100-50.56), (55.02-53.3)/(100-55.02), 0.0]}
d = {'datasets':['cifar10-ResNet18', 'cifar100-ResNet18', 'TinyImageNet-ResNet18', 'Pascal_CTX (ours)'], 'scaled deltas':[(94.12-94.05)/(100-94.05), (74.95-74.82)/(100-74.95), (50.56-50.3)/(100-50.56), 0.0]}

df = pd.DataFrame(data=d)

# %%
bar_plt = sns.barplot(data = df, x='scaled deltas', y='datasets')
